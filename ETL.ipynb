# %% [markdown]
# ### ETL con las transformaciones requeridas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Ingesto mis csv en Dataframes para saber tener una idea general de lo que contienen

# %%
df_movies=pd.read_csv(r'Datasets/movies_dataset.csv')
df_credits=pd.read_csv(r'Datasets/credits.csv')
df_movies.head()
# Out:
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_7904\2771588169.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_movies=pd.read_csv(r'Datasets/movies_dataset.csv')
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
# ...

# %%
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
# ...

# %%
df_movies.shape
# Out:
# (45466, 24)

# %% [markdown]
# Reviso valores nulos

# %%
df_movies.isna().sum()
# Out:
# adult                        0
# belongs_to_collection    40972
# budget                       0
# genres                       0
# homepage                 37684
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                   954
# popularity                   5
# poster_path                386
# production_companies         3
# production_countries         3
# release_date                87
# revenue                      6
# runtime                    263
# spoken_languages             6
# status                      87
# tagline                  25054
# title                        6
# video                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %%
df_credits.head()
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew     id
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862

# %%
df_credits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45476 entries, 0 to 45475
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   cast    45476 non-null  object
#  1   crew    45476 non-null  object
#  2   id      45476 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 1.0+ MB

# %%
df_credits.shape
# Out:
# (45476, 3)

# %% [markdown]
# ### Primero realizo mi ETL en `movies_dataset`

# %% [markdown]
# Relleno los valores nulos de budget y revenue por `0`. Como Budget no tiene valores nulos, voy a dejarlo como está.

# %%
df_movies['revenue']=df_movies['revenue'].fillna(0)

# %% [markdown]
# Elimino los valores nulos del campo release_date

# %%
df_movies=df_movies.dropna(subset=['release_date'])

# %% [markdown]
# Transformo el tipo de datos en la columna "release_date" a fecha

# %%
df_movies['release_date']=pd.to_datetime(df_movies['release_date'],format='%Y-%m-%d',errors='coerce')

# %% [markdown]
# Verifico si tengo valores nulos

# %%
df_movies['release_date'].isna().sum()
# Out:
# 3

# %% [markdown]
# Veo cuales son esos valores nulos

# %%
df_movies[df_movies['release_date'].isna()]
# Out:
#                                                    adult  \
# 19730                                 - Written by Ørnås
# 29503   Rune Balot goes to a casino connected to the ...
# 35587   Avalanche Sharks tells the story of a bikini ...
#
#       belongs_to_collection                            budget  \
# 19730              0.065736  /ff9qCepilowshEtG2GYWwzt2bs4.jpg
# 29503              1.931659  /zV8bHuSL6WXoD6FWogP9j4x80bL.jpg
# 35587              2.185485  /zaSf5OG7V8X8gqFvly88zDdRm46.jpg
#
#                                                   genres  \
# 19730  [{'name': 'Carousel Productions', 'id': 11176}...
# 29503  [{'name': 'Aniplex', 'id': 2883}, {'name': 'Go...
# 35587  [{'name': 'Odyssey Media', 'id': 17161}, {'nam...
#
#                                                 homepage          id imdb_id  \
# 19730  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...  1997-08-20       0
# 29503  [{'iso_3166_1': 'US', 'name': 'United States o...  2012-09-29       0
# ...

# %% [markdown]
# Elimino los valores nulos restantes de 'release_date'

# %%
df_movies=df_movies.dropna(subset=['release_date'])

# %% [markdown]
# Verifico nuevamente los valores nulos

# %%
df_movies['release_date'].isna().sum()
# Out:
# 0

# %% [markdown]
# Creo una nueva columna 'release_year'extrayendo la informacion de 'release_date'

# %%
df_movies['release_year']=df_movies['release_date'].dt.year

# %% [markdown]
# Creo la columna de retorno de inversion 'return', dividiendo los valores de la columna 'revenue' por los de la columna 'budget'.
#
# Para realizar esto, debo de verificar si es posible matematicamente.

# %%
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45376 entries, 0 to 45465
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45376 non-null  object
#  1   belongs_to_collection  4488 non-null   object
#  2   budget                 45376 non-null  object
#  3   genres                 45376 non-null  object
#  4   homepage               7766 non-null   object
#  5   id                     45376 non-null  object
#  6   imdb_id                45362 non-null  object
#  7   original_language      45365 non-null  object
#  8   original_title         45376 non-null  object
#  9   overview               44435 non-null  object
#  10  popularity             45376 non-null  object
#  11  poster_path            45037 non-null  object
#  12  production_companies   45376 non-null  object
#  13  production_countries   45376 non-null  object
# ...

# %% [markdown]
# Dado que la columna 'budget' esta siendo tratada como un string, procedo a modificar su tipo por float y asi corresponder con el tipo de la columna 'revenue'

# %%
df_movies['budget']=pd.to_numeric(df_movies['budget'],downcast='float',errors='coerce')

# %% [markdown]
# Realizo la division y creo la columna 'return' en el proceso.

# %%
df_movies['return']=df_movies['revenue'].divide(df_movies['budget']).fillna(0)

# %% [markdown]
# Algunos de los valores de la columna 'return' tienden a infinito, por lo cual voy a reemplazar esos valores por NaN

# %%
df_movies['return'].replace([np.inf, -np.inf], np.nan, inplace=True)

# %% [markdown]
# Relleno los NaN de 'return' por `0`

# %%
df_movies['return'].fillna(0,inplace=True)

# %% [markdown]
# Procedo a desanidar los datos que pertenecen a ciertas columnas en forma de listas y diccionarios, para crear nuevas columnas y añadirlas al dataframe.
#
# Inicio por la columna `belongs_to_colecction`

# %% [markdown]
# Relleno los valores nulos por llaves '{}', ya que de esta manera puedo usar la funcion map (eval) para reconocer que los datos son diccionarios.

# %%
df_movies['belongs_to_collection']=df_movies['belongs_to_collection'].fillna('{}')

# %% [markdown]
# Reseteo los indices, ya que elimine previamente algunas filas

# %%
df_movies = df_movies.reset_index(drop=True)

# %% [markdown]
# Utilizo json:normalize para obtener un dataframe con los datos en columnas individuales.

# %%
df1=pd.json_normalize(df_movies['belongs_to_collection'].map(eval))

# %%
df1.head()
# Out:
#          id                            name                       poster_path  \
# 0   10194.0            Toy Story Collection  /7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg
# 1       NaN                             NaN                               NaN
# 2  119050.0       Grumpy Old Men Collection  /nLvUdqgPgm3F85NMCii9gVFUcet.jpg
# 3       NaN                             NaN                               NaN
# 4   96871.0  Father of the Bride Collection  /nts4iOmNnq7GNicycMJ9pSAn204.jpg
#
#                       backdrop_path
# 0  /9FBwqcd9IRruEDUrTdcaafOMKUq.jpg
# 1                               NaN
# 2  /hypTnLot2z8wpFS7qwsQHW1uV8u.jpg
# 3                               NaN
# 4  /7qwE57OVZmMJChBpLEbJEmzUydk.jpg

# %% [markdown]
# Creo la columna 'collection_name' con la informacion de 'name'

# %%
df_movies['collection_name']=df1['name']

# %% [markdown]
# Creo 'idcollection' con la informacion de 'id'

# %%
df_movies['idcollection']=df1['id']

# %% [markdown]
# Elimino la columna 'belongs_to_collection'

# %%
df_movies.drop(columns=['belongs_to_collection'],inplace=True)

# %% [markdown]
# Elimino las columnas que no voy a utilizar (video, imdb_id, adult, original_title, poster_path y homepage).
#
# Como solo pase la informacion de las columnas de 'collection_name' y 'idcollection', ya quedo eliminada la columna 'poster_path'.

# %%
df_movies.drop(columns=['video','imdb_id','adult','original_title','poster_path','homepage'], inplace=True)

# %%
df_movies.head()
# Out:
#        budget                                             genres     id  \
# 0  30000000.0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...    862
# 1  65000000.0  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...   8844
# 2         0.0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...  15602
# 3  16000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  31357
# 4         0.0                     [{'id': 35, 'name': 'Comedy'}]  11862
#
#   original_language                                           overview  \
# 0                en  Led by Woody, Andy's toys live happily in his ...
# 1                en  When siblings Judy and Peter discover an encha...
# 2                en  A family wedding reignites the ancient feud be...
# 3                en  Cheated on, mistreated and stepped on, the wom...
# 4                en  Just when George Banks has recovered from his ...
#
#   popularity                               production_companies  \
# ...

# %% [markdown]
# Elimino el dataframe adicional df1 que cree, ya que no lo necesito.

# %%
del df1

# %% [markdown]
# Voy a transformar la columna `genres` en dos columnas, una con 'idgenres' y otra con 'genres_name'

# %% [markdown]
# Primero, voy a crear dos funciones (get_names y get_id) para extraer los nombres e id como lista.

# %%
get_names = lambda lst: [d['name'] for d in lst]
get_id = lambda lst: [d['id'] for d in lst]

# %% [markdown]
# Transformo

# %%
df_movies['genres']=df_movies['genres'].map(eval)
df_movies['genres_name'] = df_movies['genres'].apply(get_names)
df_movies['idgenres'] = df_movies['genres'].apply(get_id)

# %% [markdown]
# Elimino la columna 'genres'

# %%
df_movies.drop(columns='genres',inplace=True)
df_movies.head()
# Out:
#        budget     id original_language  \
# 0  30000000.0    862                en
# 1  65000000.0   8844                en
# 2         0.0  15602                en
# 3  16000000.0  31357                en
# 4         0.0  11862                en
#
#                                             overview popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943
# 1  When siblings Judy and Peter discover an encha...  17.015539
# 2  A family wedding reignites the ancient feud be...    11.7129
# 3  Cheated on, mistreated and stepped on, the wom...   3.859495
# 4  Just when George Banks has recovered from his ...   8.387519
#
#                                 production_companies  \
# 0     [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3  [{'name': 'Twentieth Century Fox Film Corporat...
# 4  [{'name': 'Sandollar Productions', 'id': 5842}...
#
# ...

# %% [markdown]
# Procedo a transformar la informacion de mi columna, `spoken_languages`.
#
# Creo la funcion get_slcodes, la cual me va a devolver una lista de codigos de las lenguas habladas.

# %%
get_slcodes = lambda lst: [d['iso_639_1'] for d in lst]

# %%
df_movies['spoken_languages']=df_movies['spoken_languages'].map(eval)

# %% [markdown]
# Creo dos nuevas columnas, 'slang_name' para el nombre de la lengua y 'slang_isocode' para el iso del idioma.

# %%
df_movies['slang_name'] = df_movies['spoken_languages'].apply(get_names)
df_movies['slang_isocode'] = df_movies['spoken_languages'].apply(get_slcodes)

# %% [markdown]
# Elimino la columna 'spoken_languages'

# %%
df_movies.drop(columns='spoken_languages',inplace=True)
df_movies.head()
# Out:
#        budget     id original_language  \
# 0  30000000.0    862                en
# 1  65000000.0   8844                en
# 2         0.0  15602                en
# 3  16000000.0  31357                en
# 4         0.0  11862                en
#
#                                             overview popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943
# 1  When siblings Judy and Peter discover an encha...  17.015539
# 2  A family wedding reignites the ancient feud be...    11.7129
# 3  Cheated on, mistreated and stepped on, the wom...   3.859495
# 4  Just when George Banks has recovered from his ...   8.387519
#
#                                 production_companies  \
# 0     [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3  [{'name': 'Twentieth Century Fox Film Corporat...
# 4  [{'name': 'Sandollar Productions', 'id': 5842}...
#
# ...

# %% [markdown]
# Procedo a transformar la columna `production_companies`

# %%
df_movies['production_companies']=df_movies['production_companies'].map(eval)

# %% [markdown]
# Creo las columnas 'pcompany_name' y 'idpcompany', reutilizando mis funciones previas (get_names y get_id)

# %%
df_movies['pcompany_name'] = df_movies['production_companies'].apply(get_names)
df_movies['idpcompany'] = df_movies['production_companies'].apply(get_id)

# %% [markdown]
# Elimino la columna 'production_companies'

# %%
df_movies.drop(columns='production_companies',inplace=True)
df_movies.head()
# Out:
#        budget     id original_language  \
# 0  30000000.0    862                en
# 1  65000000.0   8844                en
# 2         0.0  15602                en
# 3  16000000.0  31357                en
# 4         0.0  11862                en
#
#                                             overview popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943
# 1  When siblings Judy and Peter discover an encha...  17.015539
# 2  A family wedding reignites the ancient feud be...    11.7129
# 3  Cheated on, mistreated and stepped on, the wom...   3.859495
# 4  Just when George Banks has recovered from his ...   8.387519
#
#                                 production_countries release_date  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 3  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# ...

# %% [markdown]
# Finalmente, voy a trabajar en `production_countries`.
#
# Voy a crear una nueva funcion que obtenga las claves "iso_3166_1"

# %%
get_pccodes = lambda lst: [d['iso_3166_1'] for d in lst]

# %%
df_movies['production_countries']=df_movies['production_countries'].map(eval)

# %%
df_movies['pcountry_name'] = df_movies['production_countries'].apply(get_names)
df_movies['pcountry_isocode'] = df_movies['production_countries'].apply(get_pccodes)

# %% [markdown]
# Elimino la columna 'production_countries'

# %%
df_movies.drop(columns='production_countries',inplace=True)
df_movies.head()
# Out:
#        budget     id original_language  \
# 0  30000000.0    862                en
# 1  65000000.0   8844                en
# 2         0.0  15602                en
# 3  16000000.0  31357                en
# 4         0.0  11862                en
#
#                                             overview popularity release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  17.015539   1995-12-15
# 2  A family wedding reignites the ancient feud be...    11.7129   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...   3.859495   1995-12-22
# 4  Just when George Banks has recovered from his ...   8.387519   1995-02-10
#
#        revenue  runtime    status  \
# 0  373554033.0     81.0  Released
# 1  262797249.0    104.0  Released
# 2          0.0    101.0  Released
# 3   81452156.0    127.0  Released
# 4   76578911.0    106.0  Released
#
# ...

# %% [markdown]
# Imputo los valores nulos de mi campo 'runtime' con la media de los valores

# %%
median_runtime = df_movies['runtime'].median()
df_movies['runtime'] = df_movies['runtime'].fillna(median_runtime)

# %% [markdown]
# Elimino los valores nulos de 'original_language'

# %%
df_movies = df_movies.dropna(subset=['original_language'])

# %% [markdown]
# Corrijo los tipos de mis campos

# %%
df_movies['id'] = df_movies['id'].astype(int)
df_movies['runtime'] = df_movies['runtime'].astype(int)

# %%
df_movies.isna().sum()
# Out:
# budget                   0
# id                       0
# original_language        0
# overview               940
# popularity               0
# release_date             0
# revenue                  0
# runtime                  0
# status                  80
# tagline              24967
# title                    0
# vote_average             0
# vote_count               0
# release_year             0
# return                   0
# collection_name      40877
# idcollection         40877
# genres_name              0
# idgenres                 0
# slang_name               0
# slang_isocode            0
# pcompany_name            0
# idpcompany               0
# pcountry_name            0
# pcountry_isocode         0
# dtype: int64

# %% [markdown]
# Hasta aqui hemos terminado con el ETL de movies_datasets

# %% [markdown]
# ### Por ultimo realizo mi ETL en `credits`

# %%
print(df_credits.iloc[0, 0])
# Out:
# [{'cast_id': 14, 'character': 'Woody (voice)', 'credit_id': '52fe4284c3a36847f8024f95', 'gender': 2, 'id': 31, 'name': 'Tom Hanks', 'order': 0, 'profile_path': '/pQFoyx7rp09CJTAb932F2g8Nlho.jpg'}, {'cast_id': 15, 'character': 'Buzz Lightyear (voice)', 'credit_id': '52fe4284c3a36847f8024f99', 'gender': 2, 'id': 12898, 'name': 'Tim Allen', 'order': 1, 'profile_path': '/uX2xVf6pMmPepxnvFWyBtjexzgY.jpg'}, {'cast_id': 16, 'character': 'Mr. Potato Head (voice)', 'credit_id': '52fe4284c3a36847f8024f9d', 'gender': 2, 'id': 7167, 'name': 'Don Rickles', 'order': 2, 'profile_path': '/h5BcaDMPRVLHLDzbQavec4xfSdt.jpg'}, {'cast_id': 17, 'character': 'Slinky Dog (voice)', 'credit_id': '52fe4284c3a36847f8024fa1', 'gender': 2, 'id': 12899, 'name': 'Jim Varney', 'order': 3, 'profile_path': '/eIo2jVVXYgjDtaHoF19Ll9vtW7h.jpg'}, {'cast_id': 18, 'character': 'Rex (voice)', 'credit_id': '52fe4284c3a36847f8024fa5', 'gender': 2, 'id': 12900, 'name': 'Wallace Shawn', 'order': 4, 'profile_path': '/oGE6JqPP2xH4
# ...

# %%
print(df_credits.iloc[0, 1])
# Out:
# [{'credit_id': '52fe4284c3a36847f8024f49', 'department': 'Directing', 'gender': 2, 'id': 7879, 'job': 'Director', 'name': 'John Lasseter', 'profile_path': '/7EdqiNbr4FRjIhKHyPPdFfEEEFG.jpg'}, {'credit_id': '52fe4284c3a36847f8024f4f', 'department': 'Writing', 'gender': 2, 'id': 12891, 'job': 'Screenplay', 'name': 'Joss Whedon', 'profile_path': '/dTiVsuaTVTeGmvkhcyJvKp2A5kr.jpg'}, {'credit_id': '52fe4284c3a36847f8024f55', 'department': 'Writing', 'gender': 2, 'id': 7, 'job': 'Screenplay', 'name': 'Andrew Stanton', 'profile_path': '/pvQWsu0qc8JFQhMVJkTHuexUAa1.jpg'}, {'credit_id': '52fe4284c3a36847f8024f5b', 'department': 'Writing', 'gender': 2, 'id': 12892, 'job': 'Screenplay', 'name': 'Joel Cohen', 'profile_path': '/dAubAiZcvKFbboWlj7oXOkZnTSu.jpg'}, {'credit_id': '52fe4284c3a36847f8024f61', 'department': 'Writing', 'gender': 0, 'id': 12893, 'job': 'Screenplay', 'name': 'Alec Sokolow', 'profile_path': '/v79vlRYi94BZUQnkkyznbGUZLjT.jpg'}, {'credit_id': '52fe4284c3a36847f8024f67', 'depa
# ...

# %% [markdown]
# Reutilizo mis funciones get_names y get_id para transformar la columna 'cast'

# %%
#Transformo la informacion de mi campo 'cast'
df_credits['cast']=df_credits['cast'].map(eval)
df_credits['namecast'] = df_credits['cast'].apply(get_names)
df_credits['idcast'] = df_credits['cast'].apply(get_id)

# %%
#Elimino la columna 'cast'
df_credits.drop(columns='cast',inplace=True)
df_credits.head()
# Out:
#                                                 crew     id  \
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862
#
#                                             namecast  \
# 0  [Tom Hanks, Tim Allen, Don Rickles, Jim Varney...
# 1  [Robin Williams, Jonathan Hyde, Kirsten Dunst,...
# 2  [Walter Matthau, Jack Lemmon, Ann-Margret, Sop...
# 3  [Whitney Houston, Angela Bassett, Loretta Devi...
# 4  [Steve Martin, Diane Keaton, Martin Short, Kim...
#
#                                               idcast
# 0  [31, 12898, 7167, 12899, 12900, 7907, 8873, 11...
# 1  [2157, 8537, 205, 145151, 5149, 10739, 58563, ...
# 2       [6837, 3151, 13567, 16757, 589, 16523, 7166]
# 3  [8851, 9780, 18284, 51359, 66804, 352, 87118, ...
# ...

# %% [markdown]
# Finalmente transformo la columna 'crew'

# %%
df_credits['crew']=df_credits['crew'].apply(eval)

# %%
#funcion para extraer los campos director y name
def obtener_director(crew):
    directors = []
    for member in crew:
        if member['job'] == 'Director':
            directors.append(member['name'])
    return directors

# %%
#aplicar la funcion a la columna crew y guardar los resultados en una nueva columna directors
df_credits['directors']=df_credits['crew'].apply(obtener_director)

# %%
df_credits.drop(columns='crew',inplace=True)
df_credits.head()
# Out:
#       id                                           namecast  \
# 0    862  [Tom Hanks, Tim Allen, Don Rickles, Jim Varney...
# 1   8844  [Robin Williams, Jonathan Hyde, Kirsten Dunst,...
# 2  15602  [Walter Matthau, Jack Lemmon, Ann-Margret, Sop...
# 3  31357  [Whitney Houston, Angela Bassett, Loretta Devi...
# 4  11862  [Steve Martin, Diane Keaton, Martin Short, Kim...
#
#                                               idcast          directors
# 0  [31, 12898, 7167, 12899, 12900, 7907, 8873, 11...    [John Lasseter]
# 1  [2157, 8537, 205, 145151, 5149, 10739, 58563, ...     [Joe Johnston]
# 2       [6837, 3151, 13567, 16757, 589, 16523, 7166]    [Howard Deutch]
# 3  [8851, 9780, 18284, 51359, 66804, 352, 87118, ...  [Forest Whitaker]
# 4  [67773, 3092, 519, 70696, 59222, 18793, 14592,...    [Charles Shyer]

# %% [markdown]
# Verifico valores nulos

# %% [markdown]
# ### Procedo a unir mis datasets en uno completo para exportar el csv final

# %% [markdown]
# Uno mis dos dataframes solo donde correspondan sus "id"

# %%
df_completo = pd.merge(df_movies, df_credits, on='id', how='inner')

# %% [markdown]
# Verifico la union exitosa en base al parametro indicado 'id'

# %%
df_completo.head(3)
# Out:
#        budget     id original_language  \
# 0  30000000.0    862                en
# 1  65000000.0   8844                en
# 2         0.0  15602                en
#
#                                             overview popularity release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  17.015539   1995-12-15
# 2  A family wedding reignites the ancient feud be...    11.7129   1995-12-22
#
#        revenue  runtime    status  \
# 0  373554033.0       81  Released
# 1  262797249.0      104  Released
# 2          0.0      101  Released
#
#                                              tagline  ...         idgenres  \
# 0                                                NaN  ...  [16, 35, 10751]
# 1          Roll the dice and unleash the excitement!  ...  [12, 14, 10751]
# 2  Still Yelling. Still Fighting. Still Ready for...  ...      [10749, 35]
#
#             slang_name  slang_isocode  \
# ...

# %%
df_completo.isna().sum().sort_values(ascending = False)
# Out:
# idcollection         40943
# collection_name      40943
# tagline              25015
# overview               940
# status                  80
# budget                   0
# idcast                   0
# namecast                 0
# pcountry_isocode         0
# pcountry_name            0
# idpcompany               0
# pcompany_name            0
# slang_isocode            0
# slang_name               0
# idgenres                 0
# genres_name              0
# return                   0
# id                       0
# release_year             0
# vote_count               0
# vote_average             0
# title                    0
# runtime                  0
# revenue                  0
# release_date             0
# popularity               0
# original_language        0
# directors                0
# dtype: int64

# %% [markdown]
# Exporto mi Dataset `Data_ETL` listo para poder comenzar a crear mi API.

# %%
df_completo.shape
# Out:
# (45440, 28)

# %%
df_completo.to_csv(r'Datasets/Data_ETL.csv',index=False)
